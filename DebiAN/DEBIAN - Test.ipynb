# %% [markdown]
# # TEST github

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Multi Color MNIS

# %%
# !bash scripts/multi_color_mnist_debian.sh

# %% [markdown]
# ## bFFHQ

# %%
# !bash scripts/bffhq_debian.sh
# Out:
# ...
# [0/200] evaluating ...: 100%|█████████████████████| 8/8 [00:01<00:00,  7.76it/s]
# {'val_global_acc': 0.513, 'val_conflict_acc': nan, 'val_align_acc': 0.5130000114440918, 'val_unbiased_acc': nan, 'test_global_acc': 0.501, 'test_conflict_acc': 0.4899999797344208, 'test_align_acc': 0.5119999647140503, 'test_unbiased_acc': 0.5009999722242355}
# [1/200] ce: 0.080, l_dis: 11.341, deo: 9.770, penalty: 1.571: 100%|█| 150/150 [0
# ...
# [1/200] evaluating ...: 100%|█████████████████████| 8/8 [00:00<00:00,  9.39it/s]
# {'loss': 0.08045614669720332, 'ce_loss': 0.08045614669720332, 'bias_discover_loss': 11.34107949256897, 'bias_discover_deo_loss': 9.770045057932537, 'bias_discover_penalty_loss': 1.5710344672203065, 'val_global_acc': 0.993, 'val_conflict_acc': nan, 'val_align_acc': 0.9930000305175781, 'val_unbiased_acc': nan, 'test_global_acc': 0.745, 'test_conflict_acc': 0.49399998784065247, 'test_align_acc': 0.9959999918937683, 'test_unbiased_acc': 0.7449999898672104}
# ...

# %%
# !pipreqs .
# Out:
# INFO: Successfully saved requirements file in ./requirements.txt
